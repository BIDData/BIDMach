// %%
import $exec.^.lib.bidmach_notebook_init
if (Mat.hasCUDA > 0) GPUmem
// Out:
// 2 CUDA devices found, CUDA version 8.0
// import $exec.$
//
// res0_1: Any = (0.9634176,12314476544,12782075904)

// %%
plot(sin(row(0->1000)*0.01))
